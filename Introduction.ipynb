# %% [markdown]
# # Welcome to colab
# - ここでpythonの環境で実験などが出来ますよ
# - GPUなども使えてDeep Learningが気軽に出来たりするよ
# - まずは環境のpythonのバージョンを確認します。

# %%
import sys
print(sys.version)
# Out:
# 3.6.7 (default, Oct 22 2018, 11:32:17)
# [GCC 8.2.0]

# %% [markdown]
# - 上のように、pythonのバージョンが確認できます。
# - バージョンが3.x.xだったらOKですよ。バージョンが2.x.xの人は授業の資料を確認してバージョンを変更してくださいね。

# %% [markdown]
# # 新しいセクション
